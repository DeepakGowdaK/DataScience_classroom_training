# %% [markdown]
# # **SVM Model - Support Vector Machines**

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('3liCbRZPrZA') #https://www.youtube.com/watch?v=3liCbRZPrZA&ab_channel=udiprod

# %%
from sklearn import datasets

iris = datasets.load_iris()

x = iris.data
y = iris.target

# %%
from sklearn.svm import SVC
import sklearn

# %%
# Build Model
model = SVC()

# %%
# Split the data in training & testing datasets

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
# Train the model
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
# Predict using test data 0 y_predicted
y_predicted = model.predict(x_test)
y_expected = y_test

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_expected, y_predicted)
accuracy
# Out:
# 0.9473684210526315

# %%
# Home Work
# 1. Build SVM model and check accuracy for following datasets.
#    a. Mushroom.csv
#    b. PastHires.csv
#    c. IoT sensors.csv
